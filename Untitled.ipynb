# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=FILE&keyword=%ED%92%8D%EB%A0%A5&detailKeyword=&publicDataPk=&recmSe=N&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=_score&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=1&perPage=100&brm=&instt=&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode='
response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

else : 
    print(response.status_code)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=FILE&keyword=%ED%92%8D%EB%A0%A5&detailKeyword=&publicDataPk=&recmSe=N&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=_score&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=1&perPage=100&brm=&instt=&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode='
response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

else : 
    print(response.status_code)
    #fileDataList > div.result-list > ul > li:nth-child(6) > dl > dd
pre_selector = f'#fileDataList > div.result-list > ul > li:nth-child('
post_selector = ') > dl > dt > a > span.title'
post_selector = ') > dl > dd'
selector = '#fileDataList > div.result-list > ul > li'
selectors = []
for i in range(1,78):
    selectors.append(pre_selector+str(i)+post_selector)
for i in range(77):
    elements = soup.select(selectors[i])
    for index, element in enumerate(elements,1):
        print(f'{element.text.strip()}')
# Out:
# 속성은 단지번호, 단지명, 풍력기번호(임시), 준공일, 분류, 주소, GRS80_C_x, GRS80_C_y, lat, lon으로 구성됨
# 한국동서발전 시간대별 영광 풍력단지 내 풍력터빈 출력자료 정보입니다.
# 한국동서발전의 풍력출자회사 풍속데이터 정보입니다. 풍력출자회사 풍속데이터는 년월, 경주1단계, 경주2단계, 호남풍력발전, 백수풍력발전의 항목으로 구성됩니다.
# 한국동서발전의 영광 풍력 일간발전량 정보입니다. 영광 풍력 일간발전량은 날짜, 발전기명, 1시(kWh)~12시(kWh) 항목으로 구성됩니다.
# 한국동서발전(주)의 국산 풍력기 설치 현황 정보를 제공합니다. 발전소명, 설치일, 용량(MW), 제작사, 제품명의 항목을 나타냅니다.
# 한국남부발전의 성산풍력 일별 발전량에 대한 데이터로 기준연도, 성산 1호기, 2호기, 3호기 발전량 등의 항목을 제공합니다.
# 한국남부발전의 한경풍력 일별 발전량에 대한 데이터로 기준연도, 한경 1호기, 2호기, 3호기 발전량 등의 항목을 제공합니다.
# 2019년 풍력 일별 시간대별 5분 계량자료입니다.항목 :  거래일, 시간, 계량값단위 : Wh(시간별 5분 계량값을 합산 시 Wh의 계량값이 됩니다.)
# 2016년~2020년도 풍력 지역별 발전량 데이터입니다.
# 2010~2011년 수치모델기반 대한민국 격자별 월평균 풍력자원량 데이터로 MW급 풍력터빈의 풍력발전 사업을 위한 사전타당성 분석시 참고자료로 활용할 수 있습니다.
# 한국남부발전의 성산풍력 일평균 풍속데이터에 대한 데이터로 기준연도, 성산 1호기, 2호기, 3호기 풍속 등의 항목을 제공합니다.
# 한국남동발전의 풍력 발전 일별 풍속 데이터입니다.삼천포 발전소의 날짜에 따른 풍속 데이터로, 터빈발전기에 대한 정보와 풍속 정보를 포함하고 있습니다.
# 제주특별자치도에서 진행하고 있는 내 풍력발전시설과 관련한 데이터로 사업자, 발전소명, 위치, 규모, 사업기간 등 정보를 제공합니다.
# ...

# %%
pre_selector = f'#fileDataList > div.result-list > ul > li:nth-child('
post_selector = ') > dl > dt > a > span.title'
selector = '#fileDataList > div.result-list > ul > li'
selectors = []
for i in range(1,78):
    selectors.append(pre_selector+str(i)+post_selector)
for i in range(77):
    elements = soup.select(selectors[i])
    for index, element in enumerate(elements,1):
        print(f'{element.text.strip()}')
# Out:
# 한국에너지공단_풍력발전단지 위치정보
# 한국동서발전(주)_영광 풍력단지 내 풍력터빈 출력자료
# 한국동서발전(주)_풍력출자회사 풍속데이터
# 한국동서발전(주)_영광 풍력 일간발전량
# 한국동서발전(주)_국산 풍력기 설치 현황
# 한국남부발전(주)_성산풍력 일별 발전량
# 한국남부발전(주)_한경풍력 일별 발전량
# 한국전력거래소_5분 단위 풍력 계량데이터
# 한국전력거래소_풍력 지역별 시간별 발전량
# 한국에너지기술연구원_신재생자원지도데이터_풍력자원
# 한국남부발전(주)_성산풍력 일평균 풍속데이터
# 한국남동발전㈜_풍력 발전 일별 풍속(삼천포)
# 제주특별자치도_풍력발전현황
# 한국남동발전㈜_풍력 발전 시간대별 발전량(영흥)
# 한국남동발전㈜_풍력 발전 시간대별 풍속(삼천포)
# 한국서부발전(주)_신재생(풍력) 발전설비 예방점검기준
# 기상청_풍력기상자원지도
# 한국서부발전(주)_화순풍력발전량
# 한국전력거래소_시간별 풍력발전량
# 한국남동발전㈜_풍력 발전 시간대별 발전량(군위화산)
# 한국남부발전(주)_성산풍력발전실적
# 한국남부발전(주)_한경풍력발전실적
# 한국전력거래소_경주시 풍력 발전량
# 한국남동발전㈜_풍력 발전 시간대별 발전량(영흥ESS #1)
# 한국남동발전㈜_풍력 발전 시간대별 발전량(영흥ESS #2)
# 한국남동발전㈜_풍력 발전 시간대별 발전량(삼천포)
# 한국남부발전(주)_풍력출자회사 풍속데이터
# 한국남부발전(주)_풍력발전단지 에너지 용어 정보
# 제주에너지공사_풍력발전기 전력 정보
# 한국전력거래소_제주 태양광 풍력 발전 제어량
# 한국남동발전㈜_해상 풍력발전 개요 및 설비
# 한국남부발전(주)_한경풍력 일평균 풍속데이터
# 한국전력거래소_연간 제주 풍력 출력제한 실적
# 한국남동발전㈜_풍력 발전 시간대별 발전량_현황
# 한국동서발전(주)_영광풍력 일일 시간대별 발전량
# 전남개발공사_해상풍력 발전사업 업무추진절차
# 한국에너지공단_중대형 풍력터빈 KS인증 제품 정보
# 한국남부발전(주)_풍력발전단지 탄소저감 산림조성효과 정보
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=FILE&keyword=%ED%95%B4%EC%83%81+%ED%92%8D%EB%A0%A5&detailKeyword=&publicDataPk=&recmSe=N&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=_score&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=1&perPage=150&brm=&instt=&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode='
response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

else : 
    print(response.status_code)
    #fileDataList > div.result-list > ul > li:nth-child(6) > dl > dd
pre_selector = f'#fileDataList > div.result-list > ul > li:nth-child('
post_selector = ') > dl > dt > a > span.title'
post_selector = ') > dl > dd'
selector = '#fileDataList > div.result-list > ul > li'
selectors = []
for i in range(1,150):
    selectors.append(pre_selector+str(i)+post_selector)
for i in range(len(selectors)):
    elements = soup.select(selectors[i])
    for index, element in enumerate(elements,1):
        print(f'{element.text.strip()}')
# Out:
# 한국남동발전의 해상 풍력발전 개요 및 설비 영상입니다.탐라해상 풍력 발전소의 소개, 발전개요, 설비의 이해를 돕기위한 자료입니다.
# 해상 풍력 발전소를 건립하기 위하여 추진해야 하는 업무 절차 자료로 사업절차 구분, 사업절차 , 세부내용, 절차 중 업무상대자 및 업무유형 등을 포함한 세부내용 포함
# 한국동서발전의 해상풍력단지 일별 발전량 및 풍속 데이터 정보입니다.
# 속성은 단지번호, 단지명, 풍력기번호(임시), 준공일, 분류, 주소, GRS80_C_x, GRS80_C_y, lat, lon으로 구성됨
# 한국동서발전 시간대별 영광 풍력단지 내 풍력터빈 출력자료 정보입니다.
# 한국동서발전의 풍력출자회사 풍속데이터 정보입니다. 풍력출자회사 풍속데이터는 년월, 경주1단계, 경주2단계, 호남풍력발전, 백수풍력발전의 항목으로 구성됩니다.
# 한국동서발전의 영광 풍력 일간발전량 정보입니다. 영광 풍력 일간발전량은 날짜, 발전기명, 1시(kWh)~12시(kWh) 항목으로 구성됩니다.
# 한국동서발전(주)의 국산 풍력기 설치 현황 정보를 제공합니다. 발전소명, 설치일, 용량(MW), 제작사, 제품명의 항목을 나타냅니다.
# 한국남부발전의 성산풍력 일별 발전량에 대한 데이터로 기준연도, 성산 1호기, 2호기, 3호기 발전량 등의 항목을 제공합니다.
# 한국남부발전의 한경풍력 일별 발전량에 대한 데이터로 기준연도, 한경 1호기, 2호기, 3호기 발전량 등의 항목을 제공합니다.
# 2019년 풍력 일별 시간대별 5분 계량자료입니다.항목 :  거래일, 시간, 계량값단위 : Wh(시간별 5분 계량값을 합산 시 Wh의 계량값이 됩니다.)
# 2016년~2020년도 풍력 지역별 발전량 데이터입니다.
# ※해상범죄 발생 및 처리건수는 해상에서 발생된 모든 범죄의 범죄통계원표를 기준으로 작성되었기에 외사(外査) 범죄인 불법외국어선, 마약, 밀수, 밀입, 밀출을 포함한 통계임.
# ...
